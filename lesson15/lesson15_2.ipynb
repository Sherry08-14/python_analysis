# %%
#1家分店30天的營收

import numpy as np
np.random.seed(42)
oneStore = np.random.randint(100,10000, size=(30,))
#建立累計營收
oneStoreCum = oneStore.cumsum()
oneStoreCum
# Out:
# array([  7370,   8330,  13820,  19111,  24945,  31310,  31876,  36402,
#         42080,  50502,  52287,  53156,  60205,  62738,  68149,  73300,
#         79820,  81104,  85759,  89244,  95740, 104506, 113880, 116538,
#        124487, 126634, 129481, 138748, 139037, 141871])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont('ChineseFont.ttf')
mpl.rc('font',family='ChineseFont')
plt.plot(range(1,31),oneStoreCum,color='red',linestyle='-',marker='')
plt.title("分店營收累計")
plt.xlabel("天")
plt.ylabel("累計營收")
plt.show()

# %%
#5家分店30天的營收
import numpy as np
np.random.seed(42)
fiveStore = np.random.randint(100, 1000, size=(5, 30))
fiveStoreCum = fiveStore.cumsum(axis=1)
fiveStoreCum
# Out:
# array([[  202,   737,  1697,  2067,  2273,  2444,  3244,  3364,  4078,
#          4299,  4865,  5179,  5609,  6167,  6354,  6826,  7025,  7996,
#          8759,  8989,  9750, 10158, 11027, 11470, 12061, 12574, 13479,
#         13964, 14255, 14631],
#        [  260,   819,  1232,  1353,  1705,  2552,  3508,  4168,  4742,
#          4900,  5510,  6291,  6866,  7665,  8547,  8836,  9622, 10284,
#         11259, 11925, 12268, 13199, 13803, 14033, 14617, 15535, 16281,
#         16401, 17341, 17607],
#        [  373,   860,  1560,  1975,  2088,  2429,  3305,  3750,  4414,
#          5411,  5850,  6041,  6507,  7061,  7588,  8196,  9071,  9205,
#          9510,  9690, 10351, 11322, 11809, 11910, 12399, 13064, 13269,
#         14140, 15061, 15637],
#        [  802,  1303,  2132,  2787,  3048,  3349,  3718,  4680,  5595,
#          5965,  6520,  7081,  7907,  8258,  9059,  9454, 10278, 11097,
#         11945, 12382, 13360, 13512, 14403, 14719, 15582, 15869, 16348,
# ...

# %%
fontManager.addfont('ChineseFont.ttf')
mpl.rc('font',family='ChineseFont')
plt.plot(range(1,31),fiveStoreCum[0],color='red',linestyle='-',marker='',label='第1家分店')
plt.plot(range(1,31),fiveStoreCum[1],color='y',linestyle='-',marker='',label='第2家分店')
plt.plot(range(1,31),fiveStoreCum[2],color='g',linestyle='-',marker='',label='第3家分店')
plt.plot(range(1,31),fiveStoreCum[3],color='m',linestyle='-',marker='',label='第4家分店')
plt.plot(range(1,31),fiveStoreCum[4],color='c',linestyle='-',marker='',label='第5家分店')
plt.title("每家分店營收累計")
plt.xlabel("天")
plt.ylabel("累計營收")
plt.legend()
plt.show()
