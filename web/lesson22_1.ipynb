# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv()


client = genai.Client(api_key=os.environ['Gemini_API_KEY'])

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="天空為什麼是藍的"
)
print(response.text)

response = client.models.generate_content(
    model="gemini-1.5-pro", contents="Explain how AI works in a few words",
)
print(response.text)
# Out:
# 這是一個很棒的問題，涉及到物理學中的**「瑞利散射」（Rayleigh Scattering）**現象。簡單來說，天空之所以是藍的，是因為太陽光和大氣層中微小分子之間的相互作用。
#
# 以下是詳細解釋：
#
# 1.  **太陽光是「白色」的，但它包含所有顏色：**
#     我們看到的太陽光是白色的，但它實際上是由不同顏色的光混合而成的，就像彩虹一樣，包含紅、橙、黃、綠、藍、靛、紫等所有光譜。這些不同顏色的光有不同的**波長**——紅光的波長最長，藍光和紫光的波長最短。
#
# 2.  **地球大氣層中的微小分子：**
#     地球大氣層主要由氮氣（約78%）和氧氣（約21%）等微小分子組成，此外還有一些水蒸氣、塵埃等顆粒。這些分子和顆粒的大小都比可見光的波長要小得多。
#
# 3.  **瑞利散射：波長越短的光散射越厲害：**
#     當太陽光穿過大氣層時，會與這些微小的分子發生碰撞。由於這些分子的尺寸遠小於可見光的波長，它們會將光向四面八方散射開來。這種現象稱為「瑞利散射」。瑞利散射的特性是：**波長越短的光（如藍光和紫光），被散射的程度就越強烈；而波長越長的光（如紅光和黃光），被散射的程度就越弱。**
#
#     具體來說，藍光和紫光被散射的效率是紅光、橙光的幾倍甚至十幾倍。
#
# 4.  **天空呈現藍色的原因：**
#     當太陽光進入地球大氣層時，波長最短的藍光和紫光被大氣中的氮氣和氧氣分子大量散射開來，瀰漫在整個天空中。而波長較長的紅光、橙光和黃光則大部分能夠直接穿透大氣層到達地面。當我們抬頭看天空時，大量散射到我們眼睛裡的主要是藍光和紫光，所以天空看起來就是藍色的。
#
# 5.  **為什麼不是紫色的？**
#     你可能會問，紫光的波長比藍光更短，散射得更厲害，為什麼天空不是紫色的呢？原因有兩個：
#     *   **太陽光中的紫光本身就比藍光少：** 太陽光譜中，藍光的成分比紫光要多。
#     *   **人眼對藍光更敏感：** 我們的眼睛對藍色的敏感度遠高於對紫色的敏感度。綜合這兩個因素，我們看到的天空主要是藍色。
#
# 6.  **日出日落時天空為什麼是紅色的？**
#     在日出或日落時，太陽處於地平線附近。此時太陽光需要穿過更厚的大氣層才能到達我們的眼睛。在這麼長的傳播路徑上，絕大部分波長較短的藍光和紫光都被散射掉了，只剩下波長較長的紅光、橙光和黃光能夠穿透過來，直接進入我們的眼睛。這就是為什麼傍晚或清晨的天空會呈現出美麗的橘紅色或深紅色。
#
# 總之，天空之所以是藍色的，主要是因為太陽光中藍光和紫光的波長最短，最容易被地球大氣層中的分子散射開來，從而瀰漫在整個天空中。
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[6], line 14
#       9 response = client.models.generate_content(
#      10     model="gemini-2.5-flash", contents="天空為什麼是藍的"
#      11 )
#      12 print(response.text)
# ---> 14 response = client.models.generate_content(
#      15     model="gemini-1.5-pro", contents="Explain how AI works in a few words",
#      16 )
#      17 print(response.text)
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\google\genai\models.py:5821, in Models.generate_content(self, model, contents, config)
#    5819 while remaining_remote_calls_afc > 0:
#    5820   i += 1
# -> 5821   response = self._generate_content(
#    5822       model=model, contents=contents, config=parsed_config
#    5823   )
#    5824   logger.info(f'AFC remote call {i} is done.')
#    5825   remaining_remote_calls_afc -= 1
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\google\genai\models.py:4780, in Models._generate_content(self, model, contents, config)
#    4777 request_dict = _common.convert_to_dict(request_dict)
#    4778 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4780 response = self._api_client.request(
#    4781     'post', path, request_dict, http_options
#    4782 )
#    4784 response_dict = '' if not response.body else json.loads(response.body)
#    4786 if self._api_client.vertexai:
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\google\genai\_api_client.py:986, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     976 def request(
#     977     self,
#     978     http_method: str,
#    (...)
#     981     http_options: Optional[HttpOptionsOrDict] = None,
#     982 ) -> SdkHttpResponse:
#     983   http_request = self._build_request(
#     984       http_method, path, request_dict, http_options
#     985   )
# --> 986   response = self._request(http_request, stream=False)
#     987   response_body = response.response_stream[0] if response.response_stream else ''
#     988   return SdkHttpResponse(
#     989       headers=response.headers, body=response_body
#     990   )
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\google\genai\_api_client.py:879, in BaseApiClient._request(self, http_request, stream)
#     874 def _request(
#     875     self,
#     876     http_request: HttpRequest,
#     877     stream: bool = False,
#     878 ) -> HttpResponse:
# --> 879   return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\tenacity\__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\tenacity\__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\google\genai\_api_client.py:869, in BaseApiClient._request_once(self, http_request, stream)
#     861 else:
#     862   response = self._httpx_client.request(
#     863       method=http_request.method,
#     864       url=http_request.url,
#    (...)
#     867       timeout=http_request.timeout,
#     868   )
# --> 869   errors.APIError.raise_for_response(response)
#     870   return HttpResponse(
#     871       response.headers, response if stream else [response.text]
#     872   )
#
# File c:\Users\sherr\miniconda3\envs\myenv\lib\site-packages\google\genai\errors.py:104, in APIError.raise_for_response(cls, response)
#     102 status_code = response.status_code
#     103 if 400 <= status_code < 500:
# --> 104   raise ClientError(status_code, response_json, response)
#     105 elif 500 <= status_code < 600:
#     106   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-1.5-pro'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-1.5-pro'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-1.5-pro'}}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '53s'}]}}
